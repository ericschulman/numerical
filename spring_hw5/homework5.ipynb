# %% [markdown]
# # Question 1
#
# ## Part a
#
# $u_{xy} = \dfrac{ (u_y)_{i+1,j}^n - (u_x)_{i-1,j}^n}{2 \Delta x} + O(\Delta x^2)^2$
#
# $ (u_y)_{i+1,j} = \dfrac{u_{i+1,j+1} - u_{i+1,j-1}}{2\Delta y} + O(\Delta y^2) $
#
# $(u_x)_{i-1,j} = \dfrac{u_{i-1,j+1} - u_{i-1,j-1}}{2\Delta x} + O(\Delta x^2)$
#
# So, we have the divided difference approximation
#
#
# $u_{xy} = \dfrac{u_{i+1,j+1}^n -u_{i+1,j-1}^n - u_{i-1,j+1}^n - u_{i-1,j-1}^n}{4 \Delta x \Delta y}$
#
# ## Part b
#
# $(a(x) u_x)_x = a_x(x) u_x + a(x) u_{xx}$
#
# $u_x = \dfrac{u_{j+1}^n - u_{j-1}^n}{2 \Delta x} + O(\Delta x^2)$
#
# $u_{xx} = \dfrac{u_{j+1}^n -2 u_j^n - u_{j-1}^n}{2\Delta x} + O(\Delta x^2)$
#
# So, $(a(x) u_x)_x = a_x(x)\left( \dfrac{u_{j+1}^n - u_{j-1}^n }{2 \Delta x} \right) + a(x) \dfrac{ u_{j+1}^n - 2 u_j^n -  u_{j-1}^n }{2 \Delta x} + O(\Delta x^2) $
#
# $u_{j-1}^n = u - \Delta x u_x + \dfrac{\Delta x^2} {2} u_{xx} - \dfrac{ \Delta x^3}{6} u_{3x} + \dfrac{\Delta x^4}{24} u_{4x} - \dfrac{\Delta x^5}{120} u_{5x} + O(\Delta x^6)$
#
#
# $u_{j+1}^n = u + \Delta x u_x + \dfrac{\Delta x^2} {2} u_{xx} + \dfrac{ \Delta x^3}{6} u_{3x} + \dfrac{\Delta x^4}{24} u_{4x} + \dfrac{\Delta x^5}{120} u_{5x} + O(\Delta x^6)$
#
#
# $u_{j-2}^n = u - 2 \Delta x u_x +  2 {\Delta x^2} u_{xx} - \dfrac{4}{3} {\Delta x^3}u_{3x} + \dfrac{2}{3}{\Delta x^4} u_{4x} - \dfrac{15}{4} {\Delta x^5} u_{5x} + O(\Delta x^6)$
#
# $u_{j+2}^n = u + 2 \Delta x u_x +  2 {\Delta x^2} u_{xx} + \dfrac{4}{3} {\Delta x^3}u_{3x} - \dfrac{2}{3}{\Delta x^4} u_{4x} + \dfrac{15}{4} {\Delta x^5} u_{5x} + O(\Delta x^6)$
#
#
# ## Part c
#
# Fourth order approximiation of $u_x$ is
#
# $\dfrac{u_{j+1}-u_{j-1}}{2 \Delta x} = u_x + \dfrac{1}{6} \Delta x^2 u_{3x} +  \dfrac{1}{120} \Delta x^4 u_{5x} + 2 O(\Delta x^6) $
#
# $\dfrac{u_{j+2}-u_{j-2}}{2 \Delta x} = u_x + \dfrac{2}{3} \Delta x^2 u_{3x} + C_1 \Delta x^4 u_{5x} + 2 O(\Delta x^6)$
#
# $u_x = \left(\dfrac{4(u_{j+1} - u_{j-1}}{2 \Delta x} + \dfrac{-1(u_{j+2} - u_{j-2})}{4 \Delta x} \right) /3 + O(\Delta x^4)$
#
#
# $u_x = \dfrac{8(u_{j+1} - u_{j-1}) + u_{j+2} - u_{j-2}}{12 \Delta x} + O(\Delta x^4)$
#
#
# ## Part d
#
# $\dfrac{u_{j+1}^n - 2 u_j + u_{j-1}^n }{\Delta x^2 } = u_{xx} + \dfrac{\Delta x^2 }{12} u_{4x} + O(2 \Delta x^4)$
#
#
# $\dfrac{u_{j+2}^n - 2 u_j + u_{j-2}^n }{4 \Delta x^2 } = u_{xx} + \dfrac{\Delta x^2 }{3} u_{4x} + O(2 \Delta x^4)$
#
# $u_{xx} = \dfrac{-u_{j+2}^n + 16 u_{j+1}^n - 30 u_j^n +16 u_{j-1}^n - u_{j-2}^n }{12 \Delta x^2} + O(\Delta x^4)$

# %% [markdown]
# # Question 2
#
#
# ## Part a
# $u_j^{n+1} = \left( 1 - \dfrac{a \Delta t}{\Delta x} - \Delta t b(x_j) \right) u_j^n + \dfrac{a \Delta t}{\Delta x} u_{j-1}^n$
#
#
# $\dfrac{u+ \Delta t u_t + \Delta t^2 u_{tt}/2 + O(\Delta t^3) - u }{\Delta t } = a \left( \dfrac{u - \Delta x u_x + \Delta x^2 u_{xx}/2 + O(\Delta x^3) - u }{\Delta x}\right) - b(x_j) u_j^n$
#
# $u_t + \Delta t /2 u_{tt} + O(\Delta t) + a u_x - \Delta x u_xx/2 - b(x_j) u_j^n =0$
#
# $u_t + \Delta t /2 u_{tt} + O(\Delta t) = au_x - \Delta x/2 u_{xx} - b(x_j) u_j^n = 0$
#
# Applying PDE $u_t a u_x + b(x) u =0$ we have that $O(\Delta t + a \Delta x)$
#
# First  stick in the true solution stick in terms and cancel and then see what's left
#
#
# ## Part b
#
# This lower order term will not influence the stability. Then it is a constant coefficient problem. Then you can do standard Von Nuemann anaylsis.
#
# $e^{i (t + \Delta t + x) }  = \left(1-  \dfrac{a \Delta t}{\Delta x} - \Delta t b(x_j) \right) e^{i(x+t)} + \dfrac{a \Delta t}{\Delta x} e^{i (t + x -\Delta x)} = $
#
# $e^{i (\Delta t ) }  = \left(1-  \dfrac{a \Delta t}{\Delta x} - \Delta t b(x_j) \right) + \dfrac{a \Delta t}{\Delta x} e^{i (-\Delta x)}$
#
# As a result the scheme is stable if $ 0 \leq \dfrac{a \Delta t}{\Delta x} \leq 1$
#
# ## Part c
#
#
# We can generalize the maximize principle from the heat equation to the hyperbolic differential equation. The idea is that the maximum occurs at the boundary of $x$ or $t$ i.e. $j=0$ or $j=J$ or $n=0$
#
# Suppose that $a \dfrac{a \Delta t}{\Delta x} <1$ and $\Delta t b <1 $ then,
#
# $u^{n+1}_j = 1 - \dfrac{ a \Delta t}{\Delta x} +\dfrac{a \Delta t} {\Delta x} u_{j-1}^n - \Delta t b(x_j) u_{j-1}^n  \leq \max( u_{j-1}^n, u_j^n) - \Delta t b(x_j) u_{j-1}^n $ by Jensen's inequality.
#
# This holds reguardless of the value of $j$ or $n$, so we can inductively construct bounds on $u_j^n$. The maximum that $u_j^n$ occurs at $j=1$ and $n=1$. The term $\Delta t b(x_k)$ must also be sufficiently small.

# %% [markdown]
# # Question 3
#
# ## Part a
#
# $u_j^{n+1} = u_j^{n-1} + 2 z \left( u_{j+1}^n - u^{n+1}_j - u_j^{n-1} + u_{j-1}^n \right)$
#
# $ = u_j^{n+1} = \dfrac{1-2z}{1+2z} \hat{u}_j^{n+1} + \dfrac{4 cos(\xi) \hat{u}_j^n}{1+2z} \hat{u}_j^n$
#
# $ a(\xi)^{n+1} u_j^{0} = \dfrac{1-2z}{1+2z} a(\xi)^{n+1} u_j^{0} + \dfrac{4z cos(\xi) }{1+2z} a(\xi)^{n+1} u_j^{0} $
#
# Leting $n=1$,
#
# $a(\xi) = \dfrac{4zcos(\xi) \pm \sqrt{16z^2 cos^2(\xi) + 4 (1+2z) (1-2x) } }{2(1+2z)}$
#
# This simplifies to
#
# $a(\xi) = \dfrac{4zcos(\xi) \pm \sqrt{1 - 4z^2 sin^2(\xi) } }{2(1+2z)}$
#
# For the case when $\sqrt{1 - 4z^2 sin^2(\xi) } >0$
#
# $|a(\xi)| \leq \dfrac{2z+1}{1+2z} = 1$
#
#
# For the case when $\sqrt{1 - 4z^2 sin^2(\xi) } \leq 0$
#
# $|a(\xi)| \leq \dfrac{4z^2 -1 }{4z^2 + 4z +1} <1$
#
#
# ## Part b
#
# $u_j^{n+1} = u^{n-1}_j + \dfrac{2a \Delta t}{\Delta x^2} ( u_{j+1}^n - u_{j}^n - u_{j}^n + u_{j-1}^n)$
#
#
# $\dfrac{u_j^{n+1} - u^{n-1}_j }{2 \Delta t}=  + \dfrac{a}{\Delta x^2} ( u_{j+1}^n - u_{j}^n - u_{j}^n + u_{j-1}^n)$
#
#
# $u_t + O(\Delta t^2) = a u_{xx} + O(\Delta x^2) + O(\dfrac{\Delta t^2}{\Delta x^2})$
#
#
# $\dfrac{ u + \Delta t u_t + \dfrac{\Delta t}{2} u_{tt} + \dfrac{\Delta t^3}{6} u_{ttt} + ... - (u - \Delta t u_t + \dfrac{\Delta t}{2} u_{tt} - \dfrac{\Delta t^3}{6} u_{ttt} ...)}{2 \Delta t} = \dfrac{a}{\Delta x^2} (2u + \Delta x^2 u_{xx} + O(\Delta x^4) - u - \Delta t u_t + O(\Delta t^2) - u + \Delta t u_t + O(\Delta t^2) ) $
#
# The accuracy order is
#
# $O(\Delta x^2 , \Delta t^2, \dfrac{\Delta t^2}{\Delta x^2})$

# %% [markdown]
# # Question 4
#
# ##  Part a
#
# $u_t = u_{xx} + u_{yy} = F(u)$
#
# $ \dfrac{u_{i,j}^{n+1} - u_{i,j}^n}{\Delta t} = \dfrac{1}{2} [F_{i,j}^{n+1} + F_{i,j}^{n}] = $
#
# $ \dfrac{1}{2} \left[ \dfrac{u_{i+1,j}^{n+1} - 2u_{i,j}^{n+1} + u_{i-1,j}^{n+1} }{\Delta x^2 } + \dfrac{u_{i,j+1}^{n+1} - 2u_{i,j}^{n+1} + u_{i,j-1}^{n+1} }{\Delta y^2 }  + \dfrac{u_{i+1,j}^{n+1} - 2u_{i,j}^{n+1} + u_{i-1,j}^{n+1} }{\Delta x^2 }  +\dfrac{u_{i+1,j}^{n+1} - 2u_{i,j}^{n+1} + u_{i-1,j}^{n+1} }{\Delta y^2 }  \right]$
#
#
#
# ## Part b
#
# $\left( 1 + \dfrac{\Delta t}{\Delta y^2}  + \dfrac{\Delta t}{\Delta x^2} \right) u_{i,j}^{n+1} = \left(1 -\dfrac{\Delta t}{\Delta y^2 } - \dfrac{\Delta t }{\Delta x^2 } \right) u_{i,j}^n  + \dfrac{\Delta t} {2 \Delta x^2 \Delta y^2} \left[ \Delta y^2 u_{i+1}^{n+1} + \Delta y^2 u_{i-1,j}^{n+1} + \Delta x^2 u_{i,j+1}^{n+1} + \Delta x^2 u_{i,j-1}^{n+1} + \Delta y^2 u_{i+1,j}^n + \Delta y^2 u_{i-1,j}^n + \Delta x^2 u_{i,j+1}^n + \Delta x^2 u_{i,j-1}^n \right]$
#
# $ = \left[ \left(1 -\dfrac{\Delta t}{\Delta y^2 } - \dfrac{\Delta t }{\Delta x^2 } \right) + \dfrac{\Delta t} {\Delta x^2 \Delta y^2} \left(\Delta y^2 cos(\xi_1) + \Delta x^2 cos(\xi_2) \right) \right] \hat{u}_{i,j}^n + \dfrac{\Delta t} {\Delta x^2 \Delta y^2} \left[ \Delta y^2 cos(\xi_1) + \Delta x^2 cos(\xi_2) \right]$

# %% [markdown]
# # Question 5
#
#
#
# Multiplying by $v$ test function we get that
#
#
# $$\int_{0}^1 u_t v + u_x v_x dx = 0$$
#
# $u(0,t) = 0 = u(1,t)$ so we choose $v(1,t) = v(0,t) =0$
#
#
# If we discretize the system so that $v_n = \phi_k(x)$ and $u = u_n = \sum \alpha_j(t) \phi_j(x)$ so we get
#
#
# $\sum_{j=1}^{J} \int_0^1 \left[ \alpha_j(t) \phi_j \phi_k + \alpha_j \phi_{j}(x) \phi_k(x) \right] dx$
#
# Writing this in matrix form we have
#
# $A\alpha + B \alpha' = 0$
#
# $ A = \begin{bmatrix} 2 & -1 & 0 &0 & 0 &...&0 \\
#  -1& 2 & -1 & 0 &0 &...&0 \\   0& -1& 2 & -1 & 0 &...&0 \\  \end{bmatrix}$
#
#
#
#  $ B = h \begin{bmatrix} 2/3 & 1/6 & 0 &0 & 0 &...&0 \\
#  1/6 & 2/3 & 1/6 & 0 &0 &...&0 \\   0& 1/6& 2/3 & 1/6 & 0 &...&0 \\  \end{bmatrix}$
#
#
#  Then $\alpha' = A/B \alpha$  applying the trapezoidal rule, we have
#
#
#  $\alpha_{n+1} = \alpha_n + \dfrac{K}{2} (-A/B \alpha_n - A/B \alpha_{n+1})$
#
#
#  $ \alpha_{n+1} = \dfrac{B - KA/2}{B+ KA/2} \alpha_n$

# %%
using LinearAlgebra
using Pkg
using PyPlot

# %%
tmin,tmax = 0,1
xmin,xmax = 0,1
dx = .1
dt = 0.004
x = collect(xmin:dx:xmax)
t = collect(tmin:dt:tmax)

#useful constants
n = size(t)[1]
m = size(x)[1]
A= dt/(dx^2)


#solution matrix
u=zeros(n,m)

u[1,:]= 0.5 .- abs.(x.-0.5)

for i=2:n
    for j=2:m-1
      u[i,j] = u[i-1,j] + A * ( u[i-1,j+1] - 2*u[i-1,j] + u[i-1,j-1]) #+ dt*u[i,j];
  end

end

#print(u)

plot(x, u[1,:], label = "u(x,0)")
i = 30
plot(x, u[i,:], label = "u(x,$(t[i]))")
plot(x,  u[n,:],label = "u(x,1)")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 0.3999999999999999
# PyObject <matplotlib.legend.Legend object at 0x7f6aae896f60>

# %%
dx = .1
dt = 0.006

tmin,tmax = 0,1
xmin,xmax = 0,1

x = collect(xmin:dx:xmax)
t = collect(tmin:dt:tmax+dt)

#useful constants
n = size(t)[1]
m = size(x)[1]
A= dt/(dx^2)

print(A)

#solution matrix
u=zeros(n,m)

u[1,:]= 0.5 .- abs.(x.-0.5)



for i=2:n
    for j=2:m-1
      u[i,j] = u[i-1,j] + A * ( u[i-1,j+1] - 2*u[i-1,j] + u[i-1,j-1] ) #+ dt*u[i,j];
  end

end


plot(x, u[1,:], label = "u(x,0)")
i = 5
#plot(x, u[i,:], label = "u(x,$(t[i]))")
plot(x,  u[n,:],label = "u(x,1)")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 0.5999999999999999
# PyObject <matplotlib.legend.Legend object at 0x7f6aae60b9b0>

# %% [markdown]
# # Question 6
#
#
# $\dfrac{ u_j^{n+1} - u_j^n}{\Delta t} = \dfrac{ u^n_{j-1} -2 u_j^n + u_{j+1}^n }{\Delta x^2}$
#
# $u_{j}^{n+1} = u_j^n + \dfrac{\Delta t} {\Delta x^2} (u^n_{j-1} -2 u_j^n + u_{j+1}^n)$

# %%
tmin,tmax = 0,1
xmin,xmax = 0,1
dx = .1
dt = 0.004
x = collect(xmin:dx:xmax)
t = collect(tmin:dt:tmax)

#useful constants
n = size(t)[1]
m = size(x)[1]
s=dt/(2*dx^2)


#solution matrix
u=zeros(n,m)
A=zeros(m,m)

 #stiffness matrix
A[1,1] = (1+2*s);
A[1,2] = -s
for j=2:m-1
  A[j,j-1] = -s;
  A[j,j] = (1+2*s);
  A[j,j+1] = -s;
end

A[m,m-1]=  -s
A[m,m] = (1+2*s);

u[1,:]= 0.5 .- abs.(x.-0.5)
v=zeros(m,1);

for i=2:n-1
  for j=2:m-1
      v[j]=s * u[i-1,j+1]+(1-2*s)*u[i-1,j]+ s*u[i-1,j-1];
  end
  w=inv(A)*v;
  u[i,:]=w;
end

plot(x, u[1,:], label = "u(x,0)")
i = 10
plot(x, u[i,:], label = "u(x,$(t[i]))")
plot(x,  u[n,:],label = "u(x,1)")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f6ab0bf3eb8>

# %%
tmin,tmax = 0,1
xmin,xmax = 0,1
dx = .1
dt = 0.006
x = collect(xmin:dx:xmax)
t = collect(tmin:dt:tmax)

#useful constants
n = size(t)[1]
m = size(x)[1]
s=dt/(2*dx^2)


#solution matrix
u=zeros(n,m)
A=zeros(m,m)
A[1,1] = (1+2*s); #stiffness matrix
A[1,2] = -s

for j=2:m-1
  A[j,j-1] = -s;
  A[j,j] = (1+2*s);
  A[j,j+1] = -s;
end

A[m,m-1]=  -s
A[m,m] = (1+2*s);

u[1,:]= 0.5 .- abs.(x.-0.5)
v=zeros(m,1);

for i=2:n-1
  
  for j=2:m-1
      v[j]=s * u[i-1,j+1]+(1-2*s)*u[i-1,j]+ s*u[i-1,j-1];
  end

  w=inv(A)*v;
  u[i,:]=w;
end

plot(x, u[1,:], label = "u(x,0)")
i = 4
plot(x, u[i,:], label = "u(x,.$(t[i]))")
plot(x,  u[n,:],label = "u(x,1)")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f6ab0b69b70>
